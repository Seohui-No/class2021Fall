# %% [markdown]
# <a href="https://colab.research.google.com/github/Seohui-No/class2021Fall/blob/main/20211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; phase = 0

A  = 440.00
C  = 523.25
F  = 698.46 
D  = 587.33
E  = 659.25	 
Eb = 622.25 
F  = 698.46 
G  = 783.99
Bb = 932.33

# %%
#나비야

notes = [G, E, E, 0, F, D, D, 0, C, D, E, F, G, G, G, 0,
         G, E, E, E, F, D, D, 0, C, E, G, G, E, E, E, 0,
         D, D, D, D, D, E, F, 0, E, E, E, E, E, F, G, 0,
         G, E, E, E, F, D, D, 0, C, E, G, G, E, E, E] 
durs = [0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25,
        0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25,
        0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 
        0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 1]

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
